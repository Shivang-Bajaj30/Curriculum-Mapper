# %%
from dotenv import load_dotenv
from docx import Document
from PIL import Image
import pytesseract
import easyocr
import os
import json
import time
import google.generativeai as genai

load_dotenv()
# Out:
# True

# %%
# def check_api_key():
#     """
#     Check if Gemini API key is valid and working.
    
#     Returns:
#         dict: Status information about the API key
#     """
#     print("🔍 Checking Gemini API key...")
    
#     # Get API key - try ANTHROPIC_API_KEY first (from .env), then GEMINI_API_KEY
#     api_key = os.getenv('GEMINI_API_KEY')
    
#     if not api_key or api_key == '':
#         return {
#             "status": "❌ ERROR",
#             "message": "No API key found. Please set ANTHROPIC_API_KEY or GEMINI_API_KEY in your .env file.",
#             "valid": False
#         }
    
#     # Mask API key for display (show first 7 and last 4 characters)
#     masked_key = f"{api_key[:7]}...{api_key[-4:]}" if len(api_key) > 11 else "***"
#     print(f"📝 API Key: {masked_key}")
    
#     try:
#         genai.configure(api_key=api_key)
        
#         # Make a simple test call
#         print("🧪 Testing API connection...")
#         model = genai.GenerativeModel('gemini-pro')
#         response = model.generate_content("Say 'OK'")
        
#         result_text = response.text.strip()
        
#         print(f"✅ API Key is VALID!")
#         print(f"📤 Response: {result_text}")
        
#         return {
#             "status": "✅ VALID",
#             "message": "API key is working correctly",
#             "valid": True,
#             "model_tested": "gemini-pro",
#             "response": result_text
#         }
        
#     except Exception as e:
#         error_msg = str(e)
#         print(f"❌ API Key check FAILED: {error_msg}")
        
#         return {
#             "status": "❌ ERROR",
#             "message": error_msg,
#             "valid": False
#         }

# # Run the check
# api_status = check_api_key()
# print("\n" + "=" * 60)
# print("API KEY STATUS SUMMARY:")
# print("=" * 60)
# print(json.dumps(api_status, indent=2))

# %%
# List available models
api_key = os.getenv('GEMINI_API_KEY')

if api_key:
    genai.configure(api_key=api_key)
    
    print("🔍 Available Gemini Models:")
    print("=" * 60)
    try:
        for model in genai.list_models():
            if 'generateContent' in model.supported_generation_methods:
                print(f" • {model.name}")
    except Exception as e:
        print(f"Error connecting to Gemini: {e}")
else:
    print("Error: GEMINI_API_KEY not found in environment variables.")
# Out:
# 🔍 Available Gemini Models:
# ============================================================
#  • models/gemini-2.5-flash
#  • models/gemini-2.5-pro
#  • models/gemini-2.0-flash
#  • models/gemini-2.0-flash-001
#  • models/gemini-2.0-flash-exp-image-generation
#  • models/gemini-2.0-flash-lite-001
#  • models/gemini-2.0-flash-lite
#  • models/gemini-2.5-flash-preview-tts
#  • models/gemini-2.5-pro-preview-tts
#  • models/gemma-3-1b-it
#  • models/gemma-3-4b-it
#  • models/gemma-3-12b-it
#  • models/gemma-3-27b-it
#  • models/gemma-3n-e4b-it
#  • models/gemma-3n-e2b-it
#  • models/gemini-flash-latest
#  • models/gemini-flash-lite-latest
#  • models/gemini-pro-latest
#  • models/gemini-2.5-flash-lite
#  • models/gemini-2.5-flash-image
#  • models/gemini-2.5-flash-lite-preview-09-2025
#  • models/gemini-3-pro-preview
#  • models/gemini-3-flash-preview
#  • models/gemini-3.1-pro-preview
#  • models/gemini-3.1-pro-preview-customtools
#  • models/gemini-3-pro-image-preview
#  • models/nano-banana-pro-preview
#  • models/gemini-3.1-flash-image-preview
#  • models/gemini-robotics-er-1.5-preview
#  • models/gemini-2.5-computer-use-preview-10-2025
#  • models/deep-research-pro-preview-12-2025

# %%
def extract_text(filepath, ocr_method='easyocr', languages=['en']):
    """
    Extract text from any document type (PDF, DOCX, or Image).
    Works as standard for all document formats.
    
    Args:
        filepath (str): Path to document file
        ocr_method (str): 'easyocr' for images (default)
        languages (list): Languages for OCR (default: English)
        
    Returns:
        str: Extracted text from document
    """
    file_ext = os.path.splitext(filepath)[1].lower()
    
    try:
        # Handle PDF files
        if file_ext == '.pdf':
            import fitz
            text = ""
            doc = fitz.open(filepath)
            for page_num, page in enumerate(doc):
                text += f"\n--- Page {page_num + 1} ---\n"
                text += page.get_text()
            doc.close()
            return text
        
        # Handle Word documents
        elif file_ext == '.docx':
            from docx import Document
            text = ""
            doc = Document(filepath)
            for para in doc.paragraphs:
                if para.text.strip():
                    text += para.text + "\n"
            for table in doc.tables:
                for row in table.rows:
                    row_text = [cell.text for cell in row.cells]
                    text += " | ".join(row_text) + "\n"
            return text
        
        # Handle image files
        elif file_ext in ['.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff']:
            reader = easyocr.Reader(languages)
            results = reader.readtext(filepath)
            text = " ".join([detection[1] for detection in results])
            return text
        
        else:
            print(f"❌ Error: Unsupported file type '{file_ext}'")
            return ""
    
    except Exception as e:
        print(f"❌ Error extracting text: {str(e)}")
        return ""

# %%
def extract_information_ai(text, extraction_instructions=None, max_retries=3, retry_delay=5):
    """
    Use Google Gemini AI to intelligently extract relevant information from document.
    Automatically filters out irrelevant content, boilerplate, and noise.
    Includes automatic retry logic for transient API errors.
    
    Args:
        text (str): Full extracted document text
        extraction_instructions (str): Specific instructions on what to extract
        max_retries (int): Maximum number of retry attempts (default: 3)
        retry_delay (int): Base delay in seconds between retries (default: 5)
        
    Returns:
        dict: Extracted information as structured JSON
    """
    # Get API key from environment variable - try ANTHROPIC_API_KEY first, then GEMINI_API_KEY
    api_key = os.getenv('ANTHROPIC_API_KEY') or os.getenv('GEMINI_API_KEY')
    if not api_key:
        return {
            "error": "No API key found. Please set ANTHROPIC_API_KEY or GEMINI_API_KEY in your .env file.",
            "retries_attempted": 0,
            "note": "Set API key environment variable before running.",
            "model_used": None
        }
    genai.configure(api_key=api_key)
    
    if extraction_instructions is None:
        extraction_instructions = """Extract all important and relevant information from this document.
        Ignore filler, boilerplate, headers, footers, and irrelevant content.
        Return comprehensive structured data with all key details."""
    
    # Truncate text if too long (Gemini has 32k context, but we'll be conservative)
    MAX_TEXT_LENGTH = 50000  # Leave room for prompt
    original_text_length = len(text)
    if len(text) > MAX_TEXT_LENGTH:
        print(f"⚠️  Text is very long ({len(text)} chars). Truncating to {MAX_TEXT_LENGTH} chars...")
        text = text[:MAX_TEXT_LENGTH] + "\n\n[Document truncated due to length...]"
    
    prompt = f"""You are an expert information extraction specialist.

Your task: {extraction_instructions}

From the document below, extract ONLY the most important and relevant information.
Ignore any irrelevant, redundant, boilerplate, footer, or noise content.

IMPORTANT JSON FORMAT REQUIREMENT FOR TOPICS ONLY:
- Extract all other information normally in their respective fields (course details, faculty, assessments, etc.)
- For topics: Collect ALL topics from the document (from all units, weeks, sections) and combine them into a SINGLE "topics" array
- If topics appear in multiple places (Unit 1 topics, Unit 2 topics, weekly topics, etc.), merge them all into one "topics" array
- Each topic should be a string in the array
- Example: {{"course_code": "...", "faculty": {{...}}, "topics": ["Topic from Unit 1", "Topic from Unit 2", "Topic from Week 1", ...], "assessments": {{...}}}}

Return the extracted information as valid JSON. Be comprehensive but concise.

DOCUMENT:
---
{text}
---

Return ONLY valid JSON format. No additional text or explanation. Keep all other fields separate, but combine ALL topics into one "topics" array."""
    
    models_to_try = ["gemini-2.5-flash", "gemini-2.5-pro"]
    current_model_idx = 0
    last_error = None
    successful_model = None
    
    for attempt in range(1, max_retries + 1):
        try:
            # Try current model
            model_name = models_to_try[current_model_idx]
            
            if attempt > 1:
                print(f"🔄 Retrying with {model_name} (attempt {attempt}/{max_retries})...")
            
            # Initialize Gemini model
            model = genai.GenerativeModel(model_name)
            response = model.generate_content(prompt)
            
            response_text = response.text.strip()
            successful_model = model_name
            
            try:
                result = json.loads(response_text)
                return {
                    "extracted_information": result,
                    "model_used": successful_model
                }
            except json.JSONDecodeError:
                return {
                    "extracted_information": {"extracted_content": response_text},
                    "model_used": successful_model
                }
        
        except Exception as e:
            # Handle any API errors
            last_error = str(e)
            error_str_lower = last_error.lower()
            
            print(f"❌ Error with {models_to_try[current_model_idx]} (attempt {attempt}/{max_retries}): {last_error}")
            
            # Determine if we should retry
            should_retry = False
            
            if "quota" in error_str_lower or "rate_limit" in error_str_lower:
                print(f"⏳ Rate limit or quota hit. Waiting before retry...")
                should_retry = attempt < max_retries
                if should_retry:
                    wait_time = retry_delay * (2 ** (attempt - 1))
                    time.sleep(wait_time)
            elif "500" in last_error or "internal" in error_str_lower:
                print(f"🔄 Server error. Retrying...")
                should_retry = attempt < max_retries
                if should_retry:
                    time.sleep(retry_delay * attempt)
            elif attempt < max_retries:
                # Try next model
                if current_model_idx < len(models_to_try) - 1:
                    current_model_idx += 1
                    print(f"🔄 Switching to {models_to_try[current_model_idx]}...")
                    should_retry = True
                else:
                    # Retry with same model after waiting
                    should_retry = True
                    wait_time = retry_delay * attempt
                    print(f"⏳ Waiting {wait_time} seconds before retry...")
                    time.sleep(wait_time)
            
            if not should_retry:
                break
            continue
    
    # Final error return
    return {
        "error": last_error or "Unknown error during AI extraction",
        "retries_attempted": max_retries,
        "note": "Failed to extract information. Check API key and try again.",
        "model_used": None
    }

# %%
# file_path = "document.pdf"  # Change this to your actual file
# # extraction_task = "Extract all important information"  # Change to your needs

# # Example 1: Extract from PDF
# # print("=" * 60)
# # print("Extracting from PDF...")
# # print("=" * 60)
# # pdf_text = extract_text("document.pdf")
# # print(f"Extracted {len(pdf_text)} characters\n")

# # # Extract information with custom instructions
# # result = extract_information_ai(
# #     pdf_text,
# #     extraction_instructions="Extract all important facts, dates, names, and numbers"
# # )
# # print(json.dumps(result, indent=2))

# # Example 2: Extract from Word document
# print("\n" + "=" * 60)
# print("Extracting from Word document...")
# print("=" * 60)
# docx_text = extract_text("document.docx")
# print(f"Extracted {len(docx_text)} characters\n")

# result = extract_information_ai(
#     docx_text,
#     extraction_instructions="Extract key information and details"
# )
# print(json.dumps(result, indent=2))

# # # Example 3: Extract from Image
# # print("\n" + "=" * 60)
# # print("Extracting from Image...")
# # print("=" * 60)
# # img_text = extract_text("image.jpg")
# # print(f"Extracted {len(img_text)} characters\n")

# # result = extract_information_ai(
# #     img_text,
# #     extraction_instructions="Extract all text and important information"
# # )
# # print(json.dumps(result, indent=2))

# %%
file_path = "D:/INTEL_UNNATI_PROJECT/UNIT-1.pdf"

print(f"Extracting text from: {file_path}")
extracted_text = extract_text(file_path)
print(f"Extracted {len(extracted_text)} characters\n")
print("=" * 60)
print("EXTRACTED TEXT:")
print("=" * 60)
print(extracted_text)
print("=" * 60)
# Out:
# Extracting text from: D:/INTEL_UNNATI_PROJECT/UNIT-1.pdf
# Extracted 6636 characters
#
# ============================================================
# EXTRACTED TEXT:
# ============================================================
#
# --- Page 1 ---
# BCA-202-4 (RPA)
# UNIT-1
#
# Robotic Process Automation (RPA) - Beyond efficiency gains, RPA acts as a digital
# transformation catalyst.
#
# Digital Workforce Foundation: RPA bots become a new class of digital labor. They bridge
# legacy systems (which cannot communicate via APIs) and modern applications, acting as a
# non-invasive integration layer, thereby extending the life and value of existing IT
# investments.
#
# Data Democratization & Quality: Bots can extract, standardize, and consolidate data from
# disparate sources (web portals, mainframes, PDFs, Excel) into a single "source of truth." This
# creates high-quality, readily available data for analytics and business intelligence.
#
# Accelerated Implementation & ROI: Compared to traditional IT projects, RPA
# implementations are typically faster (weeks vs. months), require less coding, and offer a
# quicker, more measurable return on investment. This allows for rapid prototyping and
# scaling of automations.
#
# Enhanced Customer & Employee Experience: By automating back-office bottlenecks, RPA
# indirectly speeds up customer-facing processes (e.g., loan approval, claims processing). For
# employees, it reduces burnout from repetitive tasks, leading to higher engagement and
# retention.
#
# UiPath Business Automation Platform – The Unified Fabric
# UiPath has evolved from an RPA tool into a full-service automation platform. Its core
# philosophy is to provide a cohesive environment for the entire automation lifecycle.
#
# The Platform Pillars:
#
# Discover: Tools like UiPath Process Mining and Task Capture automatically analyze system
# logs and user interactions to identify, prioritize, and document the most valuable processes
# to automate, based on data—not guesswork.
#
# Build: UiPath Studio is the centerpiece, but the platform also offers StudioX for business
# users (citizen developers) with a simplified interface and StudioPro for advanced developers
# needing code-level control and integration capabilities.
#
# Manage: UiPath Orchestrator is the command center, but its role expands to managing not
# just robots but the entire automation pipeline, security, and AI models.
#
# Run: The robust execution engine powered by Attended & Unattended Robots, capable of
# running on-premises, in the cloud, or in hybrid environments.
#
#
# --- Page 2 ---
# Engage: UiPath Apps allows the creation of simple, powerful web applications that serve as a
# front-end for complex automations, letting users trigger and interact with bots through
# intuitive forms.
#
# Measure: Advanced analytics within Orchestrator and UiPath Insights (a dedicated analytics
# service) provide deep business intelligence on automation performance, process
# optimization opportunities, and financial impact.
#
# Core RPA Components:
# UiPath Studio (The Automation Factory)
#
# Project Types: It supports various project templates—Process (sequence-based), Flowchart
# (complex decision logic), and State Machine (for processes with distinct stages and triggers).
#
# Advanced Features: Includes Computer Vision for automating applications in virtual
# environments (VDI/Citrix) where standard selectors fail, and Document Understanding
# framework that uses AI/ML to intelligently classify and extract data from semi-structured
# documents (invoices, contracts).
#
# Integration Ecosystem: Seamlessly integrates with external technologies via HTTP, REST APIs,
# .NET assemblies, and has dedicated packages for SAP, Salesforce, Oracle, and more.
#
# UiPath Orchestrator (The Mission Control)
#
# Tenancy & Folders: Supports multi-tenancy for large enterprises or service providers,
# allowing logical isolation of automations for different departments, clients, or geographies
# using a folder structure with granular permissions.
#
# Asset Management: Securely stores and manages reusable configuration values, credentials,
# and files that can be consumed by multiple robots, centralizing configuration management.
#
# Monitoring & Alerting: Real-time logs, screenshots of bot execution for auditing, and
# configurable alerts for process failures or exceptions, enabling proactive operations.
#
# Disaster Recovery: Supports high-availability configurations and bot load balancing to ensure
# continuous operation.
#
# UiPath Robot & Assistant (The Digital Worker & Its Interface)
#
# Robot Architecture: The robot service runs in the system tray, executing jobs sent from
# Orchestrator. It uses the UiPath Executor to run processes in isolated sessions, ensuring
# stability.
#
# Assistant's Expanded Role: Beyond a launcher, it's a collaboration hub. It can suggest
# "automation opportunities" based on user activity, provide a library of personal
# automations, and act as a channel for IT to deploy new automations directly to user
# desktops.
#
# --- Page 3 ---
#
# Types of UiPath Robots: Strategic Deployment
# Attended Robots (The Personal Assistant)
#
# Deployment Model: Typically licensed per user and installed on individual workstations
# (laptops/desktops).
#
# Human-in-the-Loop: Excels in processes requiring judgment, exception handling, or
# compliance checks where a human must make a final decision. The robot handles the data
# gathering and navigation; the human provides the decision input.
#
# Example: A financial analyst uses an attended bot to pull the latest currency exchange rates,
# consolidate data from five different market reports into a single spreadsheet, and then uses
# their expertise to finalize the forecast model.
#
# Unattended Robots (The Back-Office Factory)
#
# Deployment Model: Licensed by workload/capacity, deployed on dedicated servers or virtual
# machines (often in a data center or cloud like AWS/Azure), managed entirely via
# Orchestrator.
#
# Triggers & Scalability: Can be triggered by schedules, file arrivals in a folder, emails, or API
# calls. A "robot farm" can be scaled dynamically—Orchestrator can spin up additional
# VM-based robots during peak load (e.g., month-end processing) and scale down afterward.
#
# Example: An unattended robot farm processes 50,000 insurance claims every night. It logs
# into the core system, retrieves claims from a queue, validates data against underwriting
# rules, updates the status, and generates payment instructions—all without human touch.
#
# Hybrid Scenarios: Modern processes often use both. An attended robot might collect and
# prep a complex case file, then submit it to an Orchestrator queue. An unattended robot
# would pick it up for the heavy, rules-based processing phase, and finally hand it back to a
# human for final review via another attended trigger. This creates a seamless, end-to-end
# automated workflow.
#
# ============================================================

# %%
print("\nExtracting information with AI...")
result = extract_information_ai(extracted_text)
print("\n" + "=" * 60)
print("EXTRACTED INFORMATION:")
print("=" * 60)

# Display model used separately (outside JSON)
if "model_used" in result and result["model_used"]:
    print(f"🤖 Model Used: {result['model_used']}")
    print("=" * 60)
    print("\n📄 Extracted Data (JSON):")
    print("=" * 60)

# Display the extracted information (JSON)
if "extracted_information" in result:
    print(json.dumps(result["extracted_information"], indent=2))
elif "error" in result:
    print(json.dumps(result, indent=2))
else:
    print(json.dumps(result, indent=2))
# Out:
# Extracting information with AI...
#
# ============================================================
# EXTRACTED INFORMATION:
# ============================================================
# 🤖 Model Used: gemini-2.5-flash
# ============================================================
#
# 📄 Extracted Data (JSON):
# ============================================================
# {
#   "extracted_content": "```json\n{\n  \"course_code\": \"BCA-202-4 (RPA)\",\n  \"introduction\": \"Robotic Process Automation (RPA) serves as a digital transformation catalyst, establishing a digital workforce foundation by bridging legacy and modern systems as a non-invasive integration layer. It facilitates data democratization and quality, accelerates implementation with faster ROI, and enhances both customer and employee experiences by automating repetitive tasks and bottlenecks.\",\n  \"topics\": [\n    \"Robotic Process Automation (RPA) - Beyond efficiency gains\",\n    \"Digital transformation catalyst\",\n    \"Digital Workforce Foundation\",\n    \"RPA bots as digital labor\",\n    \"Bridging legacy systems and modern applications\",\n    \"Non-invasive integration layer (RPA)\",\n    \"Extending life and value of existing IT investments\",\n    \"Data Democratization & Quality (RPA)\",\n    \"Extracting, standardizing, and consolidating data from disparate sources\",\n    \"Creating a single \\\"source of truth\\\"\",\n    \"High-quality data for analytics and business intelligence\",\n    \"Accelerated Implementation & ROI (RPA)\",\n    \"Faster RPA implementations (weeks vs. months)\",\n    \"Less coding in RPA\",\n    \"Quicker, measurable return on investment\",\n    \"Rapid prototyping and scaling of automations\",\n    \"Enhanced Customer & Employee Experience (RPA)\",\n    \"Automating back-office bottlenecks\",\n    \"Speeding up customer-facing processes (e.g., loan approval, claims processing)\",\n    \"Reducing employee burnout from repetitive tasks\",\n    \"Higher employee engagement and retention\",\n    \"UiPath Business Automation Platform \u2013 The Unified Fabric\",\n    \"Full-service automation platform\",\n    \"Cohesive environment for the entire automation lifecycle\",\n    \"Platform Pillar: Discover\",\n    \"UiPath Process Mining\",\n    \"Task Capture\",\n    \"Analyzing system logs and user interactions\",\n    \"Identifying, prioritizing, and documenting processes for automation\",\n    \"Platform Pillar: Build\",\n    \"UiPath Studio\",\n    \"StudioX for business users (citizen developers)\",\n    \"StudioPro for advanced developers\",\n    \"Platform Pillar: Manage\",\n    \"UiPath Orchestrator (command center)\",\n    \"Managing robots, automation pipeline, security, and AI models\",\n    \"Platform Pillar: Run\",\n    \"Robust execution engine\",\n    \"Attended Robots (execution)\",\n    \"Unattended Robots (execution)\",\n    \"On-premises execution environment\",\n    \"Cloud execution environment\",\n    \"Hybrid execution environments\",\n    \"Platform Pillar: Engage\",\n    \"UiPath Apps (creating web applications)\",\n    \"Front-end for complex automations\",\n    \"User interaction with bots through intuitive forms\",\n    \"Platform Pillar: Measure\",\n    \"Advanced analytics within Orchestrator\",\n    \"UiPath Insights (dedicated analytics service)\",\n    \"Deep business intelligence on automation performance\",\n    \"Process optimization opportunities\",\n    \"Financial impact of automation\",\n    \"Core RPA Components\",\n    \"UiPath Studio (The Automation Factory)\",\n    \"Studio Project Types: Process (sequence-based)\",\n    \"Studio Project Types: Flowchart (complex decision logic)\",\n    \"Studio Project Types: State Machine (for processes with distinct stages and triggers)\",\n    \"Studio Advanced Features: Computer Vision\",\n    \"Automating applications in virtual environments (VDI/Citrix)\",\n    \"Document Understanding framework (AI/ML for semi-structured documents)\",\n    \"Studio Integration Ecosystem\",\n    \"Integration via HTTP, REST APIs, .NET assemblies\",\n    \"Dedicated packages for SAP, Salesforce, Oracle\",\n    \"UiPath Orchestrator (The Mission Control)\",\n    \"Orchestrator Tenancy & Folders\",\n    \"Multi-tenancy support\",\n    \"Logical isolation of automations (departments, clients, geographies)\",\n    \"Granular permissions ...
# }
