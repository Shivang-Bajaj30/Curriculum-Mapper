# %%
import pandas as pd

# %%
df = pd.read_csv('jobs.csv')

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Admin Big Data
# 1                          Ansible Operations Engineer
# 2                            Artifactory Administrator
# 3    Artificial Intelligence / Machine Learning Leader
# 4    Artificial Intelligence / Machine Learning Sr....
# ..                                                 ...
# 201                      Web Designer (UI/UX Designer)
# 202                                      Web Developer
# 203                                WordPress Developer
# 204                                 XL Deploy Engineer
# 205                                    Zabbix Engineer
#
#                                        Job Description  \
# 0    Responsible for managing and overseeing big da...
# 1    Focuses on automating IT processes using Ansib...
# 2    Manages the Artifactory repository for build a...
# 3    Leads AI/ML projects and teams, defining strat...
# 4    Senior role overseeing multiple AI/ML initiati...
# ..                                                 ...
# 201  Create front end web application using HTML, C...
# 202  Develops and maintains websites and web applic...
# 203  Creates and customizes WordPress websites. Res...
# 204  Manages deployment processes using XL Deploy. ...
# 205  Implements Zabbix monitoring solutions to trac...
#
#                                                 Skills  \
# 0    Hadoop, Spark, MapReduce, Data Lakes, Data War...
# 1    Ansible, Linux, Automation, Cloud Platforms, C...
# 2    Artifactory, CI/CD, Jenkins, Docker, Maven, Gr...
# 3    AI Strategy, Machine Learning, Team Management...
# 4    AI Strategy, Machine Learning, Team Management...
# ..                                                 ...
# 201  UI/UX Design, Wireframing, Prototyping, Adobe ...
# 202  HTML5, CSS3, JavaScript, React, Node.js, Angul...
# 203     WordPress, PHP, MySQL, HTML5, CSS3, JavaScript
# 204  XL Deploy, Deployment Automation, CI/CD, Versi...
# 205  Zabbix, Monitoring Tools, Alerting Systems, Ne...
#
#                                         Certifications
# 0    Cloudera Certified Professional (CCP), Hortonw...
# 1    Red Hat Certified Specialist in Ansible Automa...
# 2    JFrog Artifactory Certification, DevOps Instit...
# 3    AI-900: Microsoft Azure AI Fundamentals, Certi...
# 4    Certified Artificial Intelligence Practitioner...
# ..                                                 ...
# 201                                                NaN
# 202                                                NaN
# 203                                                NaN
# 204  XL Deploy Certification, DevOps Institute Cert...
# 205  Zabbix Certified Specialist, Zabbix Certified ...
#
# [206 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Job Description', 'Skills', 'Certifications'], dtype='object')

# %%
df = df.rename(columns={
    'Job Description': 'job_description',
    'Job Title': 'job_title',
    'Skills': 'skills',
    'Certifications': 'certifications',
})

# %%
df
# Out:
#                                              job_title  \
# 0                                       Admin Big Data
# 1                          Ansible Operations Engineer
# 2                            Artifactory Administrator
# 3    Artificial Intelligence / Machine Learning Leader
# 4    Artificial Intelligence / Machine Learning Sr....
# ..                                                 ...
# 201                      Web Designer (UI/UX Designer)
# 202                                      Web Developer
# 203                                WordPress Developer
# 204                                 XL Deploy Engineer
# 205                                    Zabbix Engineer
#
#                                        job_description  \
# 0    Responsible for managing and overseeing big da...
# 1    Focuses on automating IT processes using Ansib...
# 2    Manages the Artifactory repository for build a...
# 3    Leads AI/ML projects and teams, defining strat...
# 4    Senior role overseeing multiple AI/ML initiati...
# ..                                                 ...
# 201  Create front end web application using HTML, C...
# 202  Develops and maintains websites and web applic...
# 203  Creates and customizes WordPress websites. Res...
# 204  Manages deployment processes using XL Deploy. ...
# 205  Implements Zabbix monitoring solutions to trac...
#
#                                                 skills  \
# 0    Hadoop, Spark, MapReduce, Data Lakes, Data War...
# 1    Ansible, Linux, Automation, Cloud Platforms, C...
# 2    Artifactory, CI/CD, Jenkins, Docker, Maven, Gr...
# 3    AI Strategy, Machine Learning, Team Management...
# 4    AI Strategy, Machine Learning, Team Management...
# ..                                                 ...
# 201  UI/UX Design, Wireframing, Prototyping, Adobe ...
# 202  HTML5, CSS3, JavaScript, React, Node.js, Angul...
# 203     WordPress, PHP, MySQL, HTML5, CSS3, JavaScript
# 204  XL Deploy, Deployment Automation, CI/CD, Versi...
# 205  Zabbix, Monitoring Tools, Alerting Systems, Ne...
#
#                                         certifications
# 0    Cloudera Certified Professional (CCP), Hortonw...
# 1    Red Hat Certified Specialist in Ansible Automa...
# 2    JFrog Artifactory Certification, DevOps Instit...
# 3    AI-900: Microsoft Azure AI Fundamentals, Certi...
# 4    Certified Artificial Intelligence Practitioner...
# ..                                                 ...
# 201                                                NaN
# 202                                                NaN
# 203                                                NaN
# 204  XL Deploy Certification, DevOps Institute Cert...
# 205  Zabbix Certified Specialist, Zabbix Certified ...
#
# [206 rows x 4 columns]

# %% [markdown]
# DATA CLEANING

# %%
(df.isna().sum().sum() / 206) * 100 #less than 30% of whole data, then drop it.
# Out:
# np.float64(24.271844660194176)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# job_title          0
# job_description    0
# skills             0
# certifications     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 205
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        157 non-null    object
#  1   job_description  157 non-null    object
#  2   skills           157 non-null    object
#  3   certifications   157 non-null    object
# dtypes: object(4)
# memory usage: 6.1+ KB

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['job_title', 'job_description', 'skills', 'certifications'], dtype='object')

# %%
df = df.drop_duplicates(subset=["job_description"]).reset_index(drop=True)
print("Rows:", len(df))
print("Unique job_description:", df["job_description"].nunique())
# Out:
# Rows: 150
# Unique job_description: 150
# 0    responsible for managing and overseeing big da...
# 1    focuses on automating it processes using ansib...
# 2    manages the artifactory repository for build a...
# 3    leads ai/ml projects and teams, defining strat...
# 4    senior role overseeing multiple ai/ml initiati...
# Name: job_description, dtype: object
